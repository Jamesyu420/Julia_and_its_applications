# %% [markdown]
# # 广播和向量化

# %%
using BenchmarkTools
using Plots

# %%
using Pluto
Pluto.run(port=1234)
# Out:
# Opening http://localhost:1234/?secret=64ufOApo in your default browser... ~ have fun!
#
# Press Ctrl+C in this terminal to stop Pluto
# ┌ Error: Pkg error: you might need to use
# │
# │ Pluto.reset_notebook_environment(notebook_path)
# │
# │ to reset this notebook's environment.
# │
# │ Before doing so, consider sending your notebook file to https://github.com/fonsp/Pluto.jl/issues together with the following info:
# │   Pluto.PLUTO_VERSION = 0.17.0
# │   VERSION = 1.6.2
# │   exception = (MethodError(Pkg.Operations.project_rel_path, (Pkg.Types.Context(Pkg.Types.EnvCache("C:\\Users\\james\\AppData\\Local\\Temp\\jl_LHaOOw\\Project.toml", "C:\\Users\\james\\AppData\\Local\\Temp\\jl_LHaOOw\\Project.toml", "C:\\Users\\james\\AppData\\Local\\Temp\\jl_LHaOOw\\Manifest.toml", nothing, Pkg.Types.Project(Dict{String, Any}("deps" => Dict{String, Any}("MLDatasets" => "eb30cadb-4394-5ae3-aed4-317e484a6458", "Images" => "916415d5-f1e6-5110-898d-aaa5f9f070e0", "PlutoUI" => "7f904dfe-b85e-4ff6-b463-dae2292396a8", "Plots" => "91a5bcdd-55d7-5caf-9e0b-520d859cae80", "BenchmarkTools" => "6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf", "TestImages" => "5e47fb64-e119-507b-a336-dd2b206d9990"), "compat" => Dict{String, Any}("MLDatasets" => "~0.5.12", "Images" => "~0.24.1", "PlutoUI" => "~0.7.16", "Plots" => "~1.23.1", "BenchmarkTools" => "~1.2.0", "TestImages" => "~1.6.2")), nothing, nothing, nothing, nothing, Dict{String, Base.UUID}("MLDatasets" => UUID("eb30cadb-4394-5ae3-aed4-317e484a6458"), "Images" => UUID("916415d5-f1e6-5110-898d-aaa5f9f070e0"), "PlutoUI" => UUID("7f904dfe-b85e-4ff6-b463-dae2292396a8"), "Plots" => UUID("91a5bcdd-55d7-5caf-9e0b-520d859cae80"), "BenchmarkTools" => UUID("6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf"), "TestImages" => UUID("5e47fb64-e119-507b-a336-dd2b206d9990")), Dict{String, Base.UUID}(), Dict{String, Vector{String}}(), Dict("MLDatasets" => "~0.5.12", "Images" => "~0.24.1", "PlutoUI" => "~0.7.16", "Plots" => "~1.23.1", "BenchmarkTools" => "~1.2.0", "TestImages" => "~1.6.2")), Pkg.Types.Manifest(v"1.7.0-rc2", v"2.0.0", Dict{Base.UUID, Pkg.Types.PackageEntry}(UUID("69de0a69-1ddd-5017-9359-2bf0b02dc9f0") => PackageEntry(
#   name = Parsers
#   version = 2.1.1
#   tree_hash = d911b6a12ba974dabe2291c6d450094a7226b372
# ), UUID("5ced341a-0733-55b8-9ab6-a4889d929147") => PackageEntry(
#   name = Lz4_jll
#   version = 1.9.3+0
#   tree_hash = 5d494bc6e85c4c9b626ee0cab05daa4085486ab1
# ), UUID("d7e528f0-a631-5988-bf34-fe36492bcfd7") => PackageEntry(
#   name = FreeType2_jll
#   version = 2.10.4+0
#   tree_hash = 87eb71354d8ec1a96d4a7636bd57a7347dde3ef9
# ), UUID("c8ffd9c3-330d-5841-b78e-0817d7145fa1") => PackageEntry(
#   name = MbedTLS_jll
# ), UUID("4b2f31a3-9ecc-558c-b454-b3730dcb73e9") => PackageEntry(
#   name = Libmount_jll
#   version = 2.35.0+0
#   tree_hash = 9c30530bf0effd46e15e0fdcf2b8636e78cbbd73
# ), UUID("82ae8749-77ed-4fe6-ae5f-f523153014b0") => PackageEntry(
#   name = StatsAPI
#   version = 1.0.0
#   tree_hash = 1958272568dc176a1d881acb797beb909c785510
# ), UUID("ed09eef8-17a6-5b46-8889-db040fac31e3") => PackageEntry(
#   name = ComputationalResources
#   version = 0.3.2
#   tree_hash = 52cb3ec90e8a8bea0e62e275ba577ad0f74821f7
# ), UUID("9e28174c-4ba2-5203-b857-d8d62c4213ee") => PackageEntry(
#   name = BinDeps
#   version = 1.0.2
#   tree_hash = 1289b57e8cf019aede076edab0587eb9644175bd
# ), UUID("30578b45-9adc-5946-b283-645ec420af67") => PackageEntry(
#   name = URIParser
#   version = 0.4.1
#   tree_hash = 53a9f49546b8d2dd2e688d216421d050c9a31d0d
# ), UUID("dbb5928d-eab1-5f90-85c2-b9b0edb7c900") => PackageEntry(
#   name = MappedArrays
#   version = 0.4.1
#   tree_hash = e8b359ef06ec72e8c030463fe02efe5527ee5142
# ), UUID("6218d12a-5da1-5696-b52f-db25d2ecc6d1") => PackageEntry(
#   name = ImageMagick
#   version = 1.2.1
#   tree_hash = 5bc1cb62e0c5f1005868358db0692c994c3a13c6
# ), UUID("9a3f8284-a2c9-5f02-9a11-845980a1fd5c") => PackageEntry(
#   name = Random
# ), UUID("4fba245c-0d91-5ea0-9b3e-6abc04ee57a9") => PackageEntry(
#   name = ArrayInterface
#   version = 3.1.36
#   tree_hash = a8101545d6b15ff1ebc927e877e28b0ab4bc4f16
# ), UUID("8bb1440f-4735-579b-a4ab-409b98df4dab") => PackageEntry(
#   name = DelimitedFiles
# ), UUID("82e4d734-157c-48bb-816b-45c225c6df19") => PackageEntry(
#   name = ImageIO
#   version = 0.5.9
#   tree_hash = a2951c93684551467265e0e32b577914f69532be
# ), UUID("9e88b42a-f829-5b0c-bbe9-9e923198166b") => PackageEntry(
#   name = Serialization
# ), UUID("aed1982a-8fda-507f-9586-7b0439959a61") => PackageEntry(
#   name = XSLT_jll
#   version = 1.1.34+0
#   tree_hash = 91844873c4085240b95e795f692c4cec4d805f8a
# ), UUID("699a6c99-e7fa-54fc-8d76-47d257e15c1d") => PackageEntry(
#   name = SimpleTraits
#   version = 0.9.4
#   tree_hash = 5d7e3f4e11935503d3ecaf7186eac40602e7d231
# ), UUID("bd369af6-aec1-5ad0-b16a-f7cc5008161c") => PackageEntry(
#   name = Tables
#   version = 1.6.0
#   tree_hash = fed34d0e71b91734bf0a7e10eb1bb05296ddbcd0
# ), UUID("3783bdb8-4a98-5b6b-af9a-565f29a5fe9c") => PackageEntry(
#   name = TableTraits
#   version = 1.0.1
#   tree_hash = c06b2f539df1c6efa794486abfb6ed2022561a39
# ), UUID("f09324ee-3d7c-5217-9330-fc30815ba969") => PackageEntry(
#   name = Netpbm
#   version = 1.0.1
#   tree_hash = 09589171688f0039f13ebe0fdcc7288f50228b52
# ), UUID("51556ac3-7006-55f5-8cb3-34580c88182d") => PackageEntry(
#   name = ImageDistances
#   version = 0.2.13
#   tree_hash = 6378c34a3c3a216235210d19b9f495ecfff2f85f
# ), UUID("bbac6d45-d8f3-5730-bfe4-7a449cd117ca") => PackageEntry(
#   name = IdentityRanges
#   version = 0.3.1
#   tree_hash = be8fcd695c4da16a1d6d0cd213cb88090a150e3b
# ), UUID("0d47668e-0667-5a69-a72c-f761630bfb7e") => PackageEntry(
#   name = Xorg_xcb_util_renderutil_jll
#   version = 0.3.9+1
#   tree_hash = dfd7a8f38d4613b6a575253b3174dd991ca6183e
# ), UUID("739be429-bea8-5141-9913-cc70e7f3736d") => PackageEntry(
#   name = MbedTLS
#   version = 1.0.3
#   tree_hash = 1c38e51c3d08ef2278062ebceade0e46cefc96fe
# ), UUID("b27032c2-a3e7-50c8-80cd-2d36dbcbfd21") => PackageEntry(
#   name = LibCURL
# ), UUID("150eb455-5306-5404-9cee-2592286d6298") => PackageEntry(
#   name = CoordinateTransformations
#   version = 0.6.1
#   tree_hash = 6d1c23e740a586955645500bbec662476204a52c
# ), UUID("01d81517-befc-4cb6-b9ec-a95719d0359c") => PackageEntry(
#   name = RecipesPipeline
#   version = 0.4.1
#   tree_hash = 7ad0dfa8d03b7bcf8c597f59f5292801730c55b8
# ), UUID("2996bd0c-7a13-11e9-2da2-2f5ce47296a9") => PackageEntry(
#   name = ImageQualityIndexes
#   version = 0.2.2
#   tree_hash = 1198f85fa2481a3bb94bf937495ba1916f12b533
# ), UUID("83775a58-1f1d-513f-b197-d71354ab007a") => PackageEntry(
#   name = Zlib_jll
# ), UUID("02fcd773-0e25-5acc-982a-7f6622650795") => PackageEntry(
#   name = ImageTransformations
#   version = 0.8.13
#   tree_hash = e4cc551e4295a5c96545bb3083058c24b78d4cf0
# ), UUID("7746bdde-850d-59dc-9ae8-88ece973131d") => PackageEntry(
#   name = Glib_jll
#   version = 2.68.3+0
#   tree_hash = 7bf67e9a481712b3dbe9cb3dac852dc4b1162e02
# ), UUID("76f85450-5226-5b5a-8eaa-529ad045b433") => PackageEntry(
#   name = LibGit2
# ), UUID("e94cdb99-869f-56ef-bcf0-1ae2bcbe0389") => PackageEntry(
#   name = MosaicViews
#   version = 0.3.3
#   tree_hash = b34e3bc3ca7c94914418637cb10cc4d1d80d877d
# ), UUID("77ba4419-2d1f-58cd-9bb1-8ffee604a2e3") => PackageEntry(
#   name = NaNMath
#   version = 0.3.5
#   tree_hash = bfe47e760d60b82b66b61d2d44128b62e3a369fb
# ), UUID("3b182d85-2403-5c21-9c21-1e1f0cc25472") => PackageEntry(
#   name = Graphite2_jll
#   version = 1.3.14+0
#   tree_hash = 344bf40dcab1073aca04aa0df4fb092f920e4011
# ), UUID("9b13fd28-a010-5f03-acff-a1bbcff69959") => PackageEntry(
#   name = IndirectArrays
#   version = 0.5.1
#   tree_hash = c2a145a145dc03a7620af1444e0264ef907bd44f
# ), UUID("2913bbd2-ae8a-5f71-8c99-4fb6c76f3a91") => PackageEntry(
#   name = StatsBase
#   version = 0.33.12
#   tree_hash = eb35dcc66558b2dda84079b9a1be17557d32091a
# ), UUID("d38c429a-6771-53c6-b99e-75d170b6e991") => PackageEntry(
#   name = Contour
#   version = 0.5.7
#   tree_hash = 9f02045d934dc030edad45944ea80dbd1f0ebea7
# ), UUID("a2964d1f-97da-50d4-b82a-358c7fce9d89") => PackageEntry(
#   name = Wayland_jll
#   version = 1.19.0+0
#   tree_hash = 3e61f0b86f90dacb0bc0e73a0c5a83f6a8636e23
# ), UUID("b22a6f82-2f65-5046-a5b2-351ab43fb4e5") => PackageEntry(
#   name = FFMPEG_jll
#   version = 4.4.0+0
#   tree_hash = d8a578692e3077ac998b50c0217dfd67f21d1e5f
# ), UUID("dfaa095f-4041-5dcd-9319-2fabd8486b76") => PackageEntry(
#   name = x265_jll
#   version = 3.5.0+0
#   tree_hash = ee567a171cce03570d77ad3a43e90218e38937a9
# ), UUID("e2d170a0-9d28-54be-80f0-106bbe20a464") => PackageEntry(
#   name = DataValueInterfaces
#   version = 1.0.0
#   tree_hash = bfc1187b79289637fa0ef6d4436ebdfe6905cbd6
# ), UUID("6e34b625-4abd-537c-b88f-471c36dfa7a0") => PackageEntry(
#   name = Bzip2_jll
#   version = 1.0.8+0
#   tree_hash = 19a35467a82e236ff51bc17a3a44b69ef35185a2
# ), UUID("621f4979-c628-5d54-868e-fcf4e3e8185c") => PackageEntry(
#   name = AbstractFFTs
#   version = 1.0.1
#   tree_hash = 485ee0867925449198280d4af84bdb46a2a404d0
# ), UUID("35d6a980-a343-548e-a6ea-1d62b119f2f4") => PackageEntry(
#   name = ColorSchemes
#   version = 3.15.0
#   tree_hash = a851fec56cb73cfdf43762999ec72eff5b86882a
# ), UUID("cf7118a7-6976-5b1a-9a39-7adc72f591a4") => PackageEntry(
#   name = UUIDs
# ), UUID("dc8bdbbb-1ca9-579f-8c36-e416f6a65cce") => PackageEntry(
#   name = CustomUnitRanges
#   version = 1.0.2
#   tree_hash = 1a3f97f907e6dd8983b744d2642651bb162a3f7a
# ), UUID("2381bf8a-dfd0-557d-9999-79630e7b1b91") => PackageEntry(
#   name = Wayland_protocols_jll
#   version = 1.18.0+4
#   tree_hash = 2839f1c1296940218e35df0bbb220f2a79686670
# ), UUID("06e1c1a7-607b-532d-9fad-de7d9aa2abac") => PackageEntry(
#   name = TiledIteration
#   version = 0.3.1
#   tree_hash = 5683455224ba92ef59db72d10690690f4a8dc297
# ), UUID("438e738f-606a-5dbb-bf0a-cddfbfd45ab0") => PackageEntry(
#   name = PyCall
#   version = 1.92.5
#   tree_hash = 4ba3651d33ef76e24fef6a598b63ffd1c5e1cd17
# ), UUID("a98d9a8b-a2ab-59e6-89dd-64a1c18fca59") => PackageEntry(
#   name = Interpolations
#   version = 0.13.4
#   tree_hash = 61aa005707ea2cebf47c8d780da8dc9bc4e0c512
# ), UUID("0ac62f75-1d6f-5e53-bd7c-93b484bb37c0") => PackageEntry(
#   name = libass_jll
#   version = 0.15.1+0
#   tree_hash = 5982a94fcba20f02f42ace44b9894ee2b140fe47
# ), UUID("53c48c17-4a7d-5ca2-90c5-79b7896eea93") => PackageEntry(
#   name = FixedPointNumbers
#   version = 0.8.4
#   tree_hash = 335bfdceacc84c5cdf16aadc768aa5ddfc5383cc
# ), UUID("124859b0-ceae-595e-8997-d05f6a7a8dfe") => PackageEntry(
#   name = DataDeps
#   version = 0.7.7
#   tree_hash = 4f0e41ff461d42cfc62ff0de4f1cd44c6e6b3771
# ), UUID("905a6f67-0a94-5f89-b386-d35d92009cd1") => PackageEntry(
#   name = Imath_jll
#   version = 3.1.2+0
#   tree_hash = 87f7662e03a649cffa2e05bf19c303e168732d3e
# ), UUID("ea2f1a96-1ddc-540d-b46f-429655e07cfa") => PackageEntry(
#   name = Xorg_libXrender_jll
#   version = 0.9.10+4
#   tree_hash = 19560f30fd49f4d4efbe7002a1037f8c43d43b96
# ), UUID("3a884ed6-31ef-47d7-9d2a-63182c4928ed") => PackageEntry(
#   name = UnPack
#   version = 1.0.2
#   tree_hash = 387c1f73762231e86e0c9c5443ce3b4a0a9a0c2b
# ), UUID("559328eb-81f9-559d-9380-de523a88c83c") => PackageEntry(
#   name = FriBidi_jll
#   version = 1.0.10+0
#   tree_hash = aa31987c2ba8704e23c6c8ba8a4f769d5d7e4f91
# ), UUID("c22f9ab0-d5fe-5066-847c-f4bb1cd4e361") => PackageEntry(
#   name = Xorg_xcb_util_wm_jll
#   version = 0.4.1+1
#   tree_hash = e78d10aab01a4a154142c5006ed44fd9e8e31b67
# ), UUID("8197267c-284f-5f27-9208-e0e47529a953") => PackageEntry(
#   name = IntervalSets
#   version = 0.5.3
#   tree_hash = 3cc368af3f110a767ac786560045dceddfc16758
# ), UUID("09ab397b-f2b6-538f-b94a-2f83cf4a842a") => PackageEntry(
#   name = StructArrays
#   version = 0.6.3
#   tree_hash = 2ce41e0d042c60ecd131e9fb7154a3bfadbf50d3
# ), UUID("6038ab10-8711-5258-84ad-4b1120ba62dc") => PackageEntry(
#   name = Rotations
#   version = 1.0.3
#   tree_hash = 3313a251b7af2c616534e6f3764d444782cb84d7
# ), UUID("cd3eb016-35fb-5094-929b-558a96fad6f3") => PackageEntry(
#   name = HTTP
#   version = 0.9.16
#   tree_hash = 14eece7a3308b4d8be910e265c724a6ba51a9798
# ), UUID("dd4b983a-f0e5-5f8d-a1b7-129d4a5fb1ac") => PackageEntry(
#   name = LZO_jll
#   version = 2.10.1+0
#   tree_hash = e5b909bcf985c5e2605737d2ce278ed791b89be6
# ), UUID("14a3606d-f60d-562e-9121-12d972cd8159") => PackageEntry(
#   name = MozillaCACerts_jll
# ), UUID("aafaddc9-749c-510e-ac4f-586e18779b91") => PackageEntry(
#   name = CatIndices
#   version = 0.2.2
#   tree_hash = a0f80a09780eed9b1d106a1bf62041c2efc995bc
# ), UUID("6fe1bfb0-de20-5000-8ca7-80f57d26f881") => PackageEntry(
#   name = OffsetArrays
#   version = 1.10.7
#   tree_hash = c0e9e582987d36d5a61e650e6e543b9e44d9914b
# ), UUID("5c2747f8-b7ea-4ff2-ba2e-563bfd36b1d4") => PackageEntry(
#   name = URIs
#   version = 1.3.0
#   tree_hash = 97bbe755a53fe859669cd907f2d96aee8d2c1355
# ), UUID("78b55507-aeef-58d4-861c-77aaff3498b1") => PackageEntry(
#   name = Gettext_jll
#   version = 0.21.0+0
#   tree_hash = 9b02998aba7bf074d14de89f9d37ca24a1a0b046
# ), UUID("33bec58e-1273-512f-9401-5d533626f822") => PackageEntry(
#   name = Xorg_xkeyboard_config_jll
#   version = 2.27.0+4
#   tree_hash = 5c8424f8a67c3f2209646d4425f3d415fee5931d
# ), UUID("ffbed154-4ef7-542d-bbb7-c09d3a79fcae") => PackageEntry(
#   name = DocStringExtensions
#   version = 0.8.6
#   tree_hash = b19534d1895d702889b219c382a6e18010797f0b
# ), UUID("12413925-8142-5f55-bb0e-6d7ca50bb09b") => PackageEntry(
#   name = Xorg_xcb_util_image_jll
#   version = 0.4.0+1
#   tree_hash = 0fab0a40349ba1cba2c1da699243396ff8e94b97
# ), UUID("8e850ede-7688-5339-a07c-302acd2aaf8d") => PackageEntry(
#   name = nghttp2_jll
# ), UUID("458c3c95-2e84-50aa-8efc-19380b2a3a95") => PackageEntry(
#   name = OpenSSL_jll
#   version = 1.1.10+0
#   tree_hash = 15003dcb7d8db3c6c857fda14891a539a8f2705a
# ), UUID("92d709cd-6900-40b7-9082-c6be49f344b6") => PackageEntry(
#   name = IrrationalConstants
#   version = 0.1.1
#   tree_hash = 7fd44fd4ff43fc60815f8e764c0f352b83c49151
# ), UUID("d96e819e-fc66-5662-9728-84c9c7592b0a") => PackageEntry(
#   name = Parameters
#   version = 0.12.3
#   tree_hash = 34c0e9ad262e5f7fc75b10a9952ca7692cfc5fbe
# ), UUID("d1454406-59df-5ea1-beac-c340f2130bc3") => PackageEntry(
#   name = Xorg_libXinerama_jll
#   version = 1.1.4+4
#   tree_hash = 26be8b1c342929259317d8b9f7b53bf2bb73b123
# ), UUID("a4e569a6-e804-4fa4-b0f3-eef7a1d5b13e") => PackageEntry(
#   name = Tar
# ), UUID("c1c5ebd0-6772-5130-a774-d5fcae4a789d") => PackageEntry(
#   name = LAME_jll
#   version = 3.100.1+0
#   tree_hash = f6250b16881adf048549549fba48b1161acdac8c
# ), UUID("9a962f9c-6df0-11e9-0e5d-c546b8b5ee8a") => PackageEntry(
#   name = DataAPI
#   version = 1.9.0
#   tree_hash = cc70b17275652eb47bc9e5f81635981f13cea5c8
# ), UUID("2ab3a3ac-af41-5b50-aa03-7779005ae688") => PackageEntry(
#   name = LogExpFunctions
#   version = 0.3.4
#   tree_hash = 6193c3815f13ba1b78a51ce391db8be016ae9214
# ), UUID("615f187c-cbe4-4ef1-ba3b-2fcf58d6d173") => PackageEntry(
#   name = IfElse
#   version = 0.1.0
#   tree_hash = 28e837ff3e7a6c3cdb252ce49fb412c8eb3caeef
# ), UUID("3cdcf5f2-1ef4-517c-9805-6587b60abb01") => PackageEntry(
#   name = RecipesBase
#   version = 1.1.2
#   tree_hash = 44a75aa7a527910ee3d1751d1f0e4148698add9e
# ), UUID("e9f186c6-92d2-5b65-8a66-fee21dc1b490") => PackageEntry(
#   name = Libffi_jll
#   version = 3.2.2+0
#   tree_hash = 761a393aeccd6aa92ec3515e428c26bf99575b3b
# ), UUID("b99e7846-7c00-51b0-8f62-c81ae34c0232") => PackageEntry(
#   name = BinaryProvider
#   version = 0.5.10
#   tree_hash = ecdec412a9abc8db54c0efc5548c64dfce072058
# ), UUID("d25df0c9-e2be-5dd7-82c8-3ad0b3e990b9") => PackageEntry(
#   name = Inflate
#   version = 0.1.2
#   tree_hash = f5fc07d4e706b84f72d54eedcc1c13d92fb0871c
# ), UUID("5789e2e9-d7fb-5bc7-8068-2c6fae9b9549") => PackageEntry(
#   name = FileIO
#   version = 1.11.1
#   tree_hash = 3c041d2ac0a52a12a27af2782b34900d9c3ee68c
# ), UUID("8ba89e20-285c-5b6f-9357-94700520ee1b") => PackageEntry(
#   name = Distributed
# ), UUID("442fdcdd-2543-5da2-b0f3-8c86c306513e") => PackageEntry(
#   name = Measures
#   version = 0.3.1
#   tree_hash = e498ddeee6f9fdb4551ce855a46f54dbd900245f
# ), UUID("d360d2e6-b24c-11e9-a2a3-2a2ae2dbcce4") => PackageEntry(
#   name = ChainRulesCore
#   version = 1.11.0
#   tree_hash = 3533f5a691e60601fe60c90d8bc47a27aa2907ec
# ), UUID("eb30cadb-4394-5ae3-aed4-317e484a6458") => PackageEntry(
#   name = MLDatasets
#   version = 0.5.12
#   tree_hash = 3ad568c323866280500096860a5e2a76b2e7e12d
# ), UUID("c84ed2f1-dad5-54f0-aa8e-dbefe2724439") => PackageEntry(
#   name = Ratios
#   version = 0.4.2
#   tree_hash = 01d341f502250e81f6fec0afe662aa861392a3aa
# ), UUID("38a345b3-de98-5d2b-a5d3-14cd9215e700") => PackageEntry(
#   name = Libuuid_jll
#   version = 2.36.0+0
#   tree_hash = 7f3efec06033682db852f8b3bc3c1d2b0a0ab066
# ), UUID("42e2da0e-8278-4e71-bc24-59509adca0fe") => PackageEntry(
#   name = Grisu
#   version = 1.0.2
#   tree_hash = 53bb909d1151e57e2484c3d1b53e19552b887fb2
# ), UUID("52e1d378-f018-4a11-a4be-720524705ac7") => PackageEntry(
#   name = OpenEXR
#   version = 0.3.2
#   tree_hash = 327f53360fdb54df7ecd01e96ef1983536d1e633
# ), UUID("935fb764-8cf2-53bf-bb30-45bb1f8bf724") => PackageEntry(
#   name = Xorg_libXcursor_jll
#   version = 1.2.0+4
#   tree_hash = 12e0eb3bc634fa2080c1c37fccf56f7c22989afd
# ), UUID("d8fb68d0-12a3-5cfd-a85a-d49703b185fd") => PackageEntry(
#   name = xkbcommon_jll
#   version = 0.9.1+5
#   tree_hash = ece2350174195bb31de1a63bea3a41ae1aa593b6
# ), UUID("efce3f68-66dc-5838-9240-27a6d6f5f9b6") => PackageEntry(
#   name = WoodburyMatrices
#   version = 0.5.5
#   tree_hash = de67fa59e33ad156a590055375a30b23c40299d3
# ), UUID("2f01184e-e22b-5df5-ae63-d93ebab69eaf") => PackageEntry(
#   name = SparseArrays
# ), UUID("b53b4c65-9356-5827-b1ea-8c7a1a84506f") => PackageEntry(
#   name = libpng_jll
#   version = 1.6.38+0
#   tree_hash = 94d180a6d2b5e55e447e2d27a29ed04fe79eb30c
# ), UUID("856f2bd8-1eba-4b0a-8007-ebc267875bd4") => PackageEntry(
#   name = StructTypes
#   version = 1.8.1
#   tree_hash = d24a825a95a6d98c385001212dc9020d609f2d4f
# ), UUID("b5f81e59-6552-4d32-b1f0-c071b021bf89") => PackageEntry(
#   name = IOCapture
#   version = 0.2.2
#   tree_hash = f7be53659ab06ddc986428d3a9dcc95f6fa6705a
# ), UUID("18a262bb-aa17-5467-a713-aee519bc75cb") => PackageEntry(
#   name = OpenEXR_jll
#   version = 3.1.1+0
#   tree_hash = 923319661e9a22712f24596ce81c54fc0366f304
# ), UUID("4536629a-c528-5b80-bd46-f80d51c5b363") => PackageEntry(
#   name = OpenBLAS_jll
# ), UUID("3161d3a3-bdf6-5164-811a-617609db77b4") => PackageEntry(
#   name = Zstd_jll
#   version = 1.5.0+0
#   tree_hash = cc4bf3fdde8b7e3e9fa0351bdeedba1cf3b7f6e6
# ), UUID("6462fe0b-24de-5631-8697-dd941f90decc") => PackageEntry(
#   name = Sockets
# ), UUID("9abbd945-dff8-562f-b5e8-e1ebf5ef1b79") => PackageEntry(
#   name = Profile
# ), UUID("856f044c-d86e-5d09-b602-aeab76dc8ba7") => PackageEntry(
#   name = MKL_jll
#   version = 2021.1.1+2
#   tree_hash = 5455aef09b40e5020e1520f551fa3135040d4ed0
# ), UUID("92fee26a-97fe-5a0c-ad85-20a5f3185b63") => PackageEntry(
#   name = GZip
#   version = 0.5.1
#   tree_hash = 039be665faf0b8ae36e089cd694233f5dee3f7d6
# ), UUID("ea8e919c-243c-51af-8825-aaa63cd721ce") => PackageEntry(
#   name = SHA
# ), UUID("b964fa9f-0449-5b57-a5c2-d3ea65f4040f") => PackageEntry(
#   name = LaTeXStrings
#   version = 1.2.1
#   tree_hash = c7f1c695e06c01b95a67f0cd1d34994f3e7db104
# ), UUID("13072b0f-2c55-5437-9ae7-d433b7a33950") => PackageEntry(
#   name = AxisAlgorithms
#   version = 1.0.1
#   tree_hash = 66771c8d21c8ff5e3a93379480a2307ac36863f7
# ), UUID("e7412a2a-1a6e-54c0-be00-318e2571c051") => PackageEntry(
#   name = Ogg_jll
#   version = 1.3.5+0
#   tree_hash = 7937eda4681660b4d6aeeecc2f7e1c81c8ee4e2f
# ), UUID("2a0f44e3-6c83-55bd-87e4-b1978d98bd5f") => PackageEntry(
#   name = Base64
# ), UUID("cc61e674-0454-545c-8b26-ed2c68acab7a") => PackageEntry(
#   name = Xorg_libxkbfile_jll
#   version = 1.1.0+4
#   tree_hash = 926af861744212db0eb001d9e40b5d16292080b2
# ), UUID("23fbe1c1-3f47-55db-b15f-69d7ec21a316") => PackageEntry(
#   name = Latexify
#   version = 0.15.9
#   tree_hash = a8f4f279b6fa3c3c4f1adadd78a621b13a506bce
# ), UUID("29816b5a-b9ab-546f-933c-edad1886dfa8") => PackageEntry(
#   name = LibSSH2_jll
# ), UUID("88034a9c-02f8-509d-84a9-84ec65e18404") => PackageEntry(
#   name = StringDistances
#   version = 0.11.1
#   tree_hash = 00e86048552d34bb486cad935754dd9516bdb46e
# ), UUID("4ec0a83e-493e-50e2-b9ac-8f72acf5a8f5") => PackageEntry(
#   name = Unicode
# ), UUID("f638f0a6-7fb0-5443-88ba-1cc74229b280") => PackageEntry(
#   name = libfdk_aac_jll
#   version = 2.0.2+0
#   tree_hash = daacc84a041563f965be61859a36e17c4e4fcd55
# ), UUID("6a3955dd-da59-5b1f-98d4-e7296123deb5") => PackageEntry(
#   name = ImageFiltering
#   version = 0.6.21
#   tree_hash = bf96839133212d3eff4a1c3a80c57abc7cfbf0ce
# ), UUID("682c06a0-de6a-54ab-a142-c8b1cf79cde6") => PackageEntry(
#   name = JSON
#   version = 0.21.2
#   tree_hash = 8076680b162ada2a031f707ac7b4953e30667a37
# ), UUID("f43a241f-c20a-4ad4-852c-f6b1247861c6") => PackageEntry(
#   name = Downloads
# ), UUID("8f4d0f93-b110-5947-807f-2305c1781a2d") => PackageEntry(
#   name = Conda
#   version = 1.5.2
#   tree_hash = 299304989a5e6473d985212c28928899c74e9421
# ), UUID("aedffcd0-7271-4cad-89d0-dc628f76c6d3") => PackageEntry(
#   name = Static
#   version = 0.4.0
#   tree_hash = e7bc80dc93f50857a5d1e3c8121495852f407e6a
# ), UUID("d6f4376e-aef5-505a-96c1-9c027394607a") => PackageEntry(
#   name = Markdown
# ), UUID("92933f4c-e287-5a05-a399-4b506db050ca") => PackageEntry(
#   name = ProgressMeter
#   version = 1.7.1
#   tree_hash = afadeba63d90ff223a6a48d2009434ecee2ec9e8
# ), UUID("995b91a9-d308-5afd-9ec6-746e21dbc043") => PackageEntry(
#   name = PlotUtils
#   version = 1.0.15
#   tree_hash = b084324b4af5a438cd63619fd006614b3b20b87b
# ), UUID("916415d5-f1e6-5110-898d-aaa5f9f070e0") => PackageEntry(
#   name = Images
#   version = 0.24.1
#   tree_hash = 8b714d5e11c91a0d945717430ec20f9251af4bd2
# ), UUID("ca575930-c2e3-43a9-ace4-1e988b2c1908") => PackageEntry(
#   name = NetworkOptions
# ), UUID("da5c29d0-fa7d-589e-88eb-ea29b0a81949") => PackageEntry(
#   name = EllipsisNotation
#   version = 1.1.0
#   tree_hash = 8041575f021cba5a099a456b4163c9a08b566a02
# ), UUID("a51aa0fd-4e3c-5386-b890-e753decda492") => PackageEntry(
#   name = Xorg_libXi_jll
#   version = 1.7.10+4
#   tree_hash = 89b52bc2160aadc84d707093930ef0bffa641246
# ), UUID("79e6a3ab-5dfb-504d-930d-738a2a938a0e") => PackageEntry(
#   name = Adapt
#   version = 3.3.1
#   tree_hash = 84918055d15b3114ede17ac6a7182f68870c16f7
# ), UUID("59287772-0a20-5a39-b81b-1366585eb4c0") => PackageEntry(
#   name = Formatting
#   version = 0.4.2
#   tree_hash = 8339d61043228fdd3eb658d86c926cb282ae72a8
# ), UUID("ac1192a8-f4b3-4bfe-ba22-af5b92cd3ab2") => PackageEntry(
#   name = HypertextLiteral
#   version = 0.9.2
#   tree_hash = 5efcf53d798efede8fee5b2c8b09284be359bf24
# ), UUID("d2c73de3-f751-5644-a686-071e5b155ba9") => PackageEntry(
#   name = GR_jll
#   version = 0.61.0+0
#   tree_hash = cafe0823979a5c9bff86224b3b8de29ea5a44b2e
# ), UUID("5432bcbf-9aad-5242-b902-cca2824c8663") => PackageEntry(
#   name = PaddedViews
#   version = 0.5.10
#   tree_hash = 646eed6f6a5d8df6708f15ea7e02a7a2c4fe4800
# ), UUID("0656b61e-2033-5cc2-a64a-77c0f6c09b89") => PackageEntry(
#   name = GLFW_jll
#   version = 3.3.5+1
#   tree_hash = 0c603255764a1fa0b61752d2bec14cfbd18f7fe8
# ), UUID("fa267f1f-6049-4f14-aa54-33bafae1ed76") => PackageEntry(
#   name = TOML
# ), UUID("35661453-b289-5fab-8a00-3d9160c6a3a4") => PackageEntry(
#   name = Xorg_xkbcomp_jll
#   version = 1.4.2+4
#   tree_hash = 4bcbf660f6c2e714f87e960a171b119d06ee163b
# ), UUID("a63ad114-7e13-5084-954f-fe012c677804") => PackageEntry(
#   name = Mmap
# ), UUID("28b8d3ca-fb5f-59d9-8090-bfdbd6d07a71") => PackageEntry(
#   name = GR
#   version = 0.61.0
#   tree_hash = d189c6d2004f63fd3c91748c458b09f26de0efaa
# ), UUID("5c1252a2-5f33-56bf-86c9-59e7332b4326") => PackageEntry(
#   name = GeometryBasics
#   version = 0.4.1
#   tree_hash = 58bcdf5ebc057b085e58d95c138725628dd7453c
# ), UUID("81def892-9a0e-5fdd-b105-ffc91e053289") => PackageEntry(
#   name = VersionParsing
#   version = 1.2.1
#   tree_hash = e575cf85535c7c3292b4d89d89cc29e8c3098e47
# ), UUID("2803e5a7-5153-5ecf-9a86-9b4c37f5f5ac") => PackageEntry(
#   name = ImageAxes
#   version = 0.6.9
#   tree_hash = 794ad1d922c432082bc1aaa9fa8ffbd1fe74e621
# ), UUID("2def613f-5ad1-5310-b15b-b15d46f528f5") => PackageEntry(
#   name = Xorg_xcb_util_jll
#   version = 0.4.0+1
#   tree_hash = e7fd7b2881fa2eaa72717420894d3938177862d1
# ), UUID("b3c3ace0-ae52-54e7-9d0b-2c1406fd6b9d") => PackageEntry(
#   name = RangeArrays
#   version = 0.3.2
#   tree_hash = b9039e93773ddcfc828f12aadf7115b4b4d225f5
# ), UUID("f5851436-0d7a-5f13-b9de-f02708fd171a") => PackageEntry(
#   name = FFTW_jll
#   version = 3.3.10+0
#   tree_hash = c6033cc3892d0ef5bb9cd29b7f2f0331ea5184ea
# ), UUID("3f19e933-33d8-53b3-aaab-bd5110c3b7a0") => PackageEntry(
#   name = p7zip_jll
# ), UUID("f27f6e37-5d2b-51aa-960f-b287f2bc3b7a") => PackageEntry(
#   name = libvorbis_jll
#   version = 1.3.7+0
#   tree_hash = c45f4e40e7aafe9d086379e5578947ec8b95a8fb
# ), UUID("992d4aef-0814-514b-bc4d-f2e9a6c4116f") => PackageEntry(
#   name = Showoff
#   version = 1.0.3
#   tree_hash = 91eddf657aca81df9ae6ceb20b959ae5653ad1de
# ), UUID("975044d2-76e6-5fbe-bf08-97ce7c6574c7") => PackageEntry(
#   name = Xorg_xcb_util_keysyms_jll
#   version = 0.4.0+1
#   tree_hash = d1151e2c45a544f32441a567d1690e701ec89b00
# ), UUID("c73af94c-d91f-53ed-93a7-00f77d67a9d7") => PackageEntry(
#   name = ImageMagick_jll
#   version = 6.9.12+0
#   tree_hash = ea2b6fd947cdfc43c6b8c15cff982533ec1f72cd
# ), UUID("90137ffa-7385-5640-81b9-e52037218182") => PackageEntry(
#   name = StaticArrays
#   version = 1.2.13
#   tree_hash = 3c76dde64d03699e074ac02eb2e8ba8254d428da
# ), UUID("5e47fb64-e119-507b-a336-dd2b206d9990") => PackageEntry(
#   name = TestImages
#   version = 1.6.2
#   tree_hash = f91d170645a8ba6fbaa3ac2879eca5da3d92a31a
# ), UUID("f67ccb44-e63f-5c2f-98bd-6dc0ccc4ba2f") => PackageEntry(
#   name = HDF5
#   version = 0.15.7
#   tree_hash = 698c099c6613d7b7f151832868728f426abe698b
# ), UUID("1082639a-0dae-5f34-9b06-72781eeb8cb3") => PackageEntry(
#   name = Xorg_libXext_jll
#   version = 1.3.4+4
#   tree_hash = b7c0aa8c376b31e4852b360222848637f481f8c3
# ), UUID("4af54fe1-eca0-43a8-85a7-787d91b784e3") => PackageEntry(
#   name = LazyArtifacts
# ), UUID("14d82f49-176c-5ed1-bb49-ad3f5cbd8c74") => PackageEntry(
#   name = Xorg_libpthread_stubs_jll
#   version = 0.1.0+3
#   tree_hash = 6783737e45d3c59a4a4c4091f5f88cdcf0908cbb
# ), UUID("a74b3585-a348-5f62-a45c-50e91977d574") => PackageEntry(
#   name = Blosc
#   version = 0.7.0
#   tree_hash = 84cf7d0f8fd46ca6f1b3e0305b4b4a37afe50fd6
# ), UUID("944b1d66-785c-5afd-91f1-9de20f533193") => PackageEntry(
#   name = CodecZlib
#   version = 0.7.0
#   tree_hash = ded953804d019afa9a3f98981d99b33e3db7b6da
# ), UUID("c5fb5394-a638-5e4d-96e5-b29de1b5cf10") => PackageEntry(
#   name = Xorg_xtrans_jll
#   version = 1.4.0+3
#   tree_hash = 79c31e7844f6ecf779705fbc12146eb190b7d845
# ), UUID("2e76f6c2-a576-52d4-95c1-20adfe4de566") => PackageEntry(
#   name = HarfBuzz_jll
#   version = 2.8.1+0
#   tree_hash = 8a954fed8ac097d5be04921d595f741115c1b2ad
# ), UUID("21216c6a-2e73-6563-6e65-726566657250") => PackageEntry(
#   name = Preferences
#   version = 1.2.2
#   tree_hash = 00cfd92944ca9c760982747e9a1d0d5d86ab1e5a
# ), UUID("a2af1166-a08f-5f64-846c-94a0d3cef48c") => PackageEntry(
#   name = SortingAlgorithms
#   version = 1.0.1
#   tree_hash = b3363d7460f7d098ca0912c69b082f75625d7508
# ), UUID("1270edf5-f2f9-52d2-97e9-ab00b5d0237a") => PackageEntry(
#   name = x264_jll
#   version = 2021.5.5+0
#   tree_hash = 4fea590b89e6ec504593146bf8b988b2c00922b2
# ), UUID("0c0b7dd1-d40b-584c-a123-a41640f87eec") => PackageEntry(
#   name = Xorg_libXau_jll
#   version = 1.0.9+4
#   tree_hash = 4e490d5c960c314f33885790ed410ff3a94ce67e
# ), UUID("2f80f16e-611a-54ab-bc61-aa92de5b98fc") => PackageEntry(
#   name = PCRE_jll
#   version = 8.44.0+0
#   tree_hash = b2a7af664e098055a7529ad1a900ded962bca488
# ), UUID("e1d29d7a-bbdc-5cf2-9ac0-f12de2c33e28") => PackageEntry(
#   name = Missings
#   version = 1.0.2
#   tree_hash = bf210ce90b6c9eed32d25dbcae1ebc565df2687f
# ), UUID("05823500-19ac-5b8b-9628-191a04bc5112") => PackageEntry(
#   name = OpenLibm_jll
# ), UUID("3fa0cd96-eef1-5676-8a61-b3b8758bbffb") => PackageEntry(
#   name = REPL
# ), UUID("8e850b90-86db-534c-a0d3-1478176c7d93") => PackageEntry(
#   name = libblastrampoline_jll
# ), UUID("47d2ed2b-36de-50cf-bf87-49c2cf4b8b91") => PackageEntry(
#   name = Hyperscript
#   version = 0.0.4
#   tree_hash = 8d511d5b81240fc8e6802386302675bdf47737b9
# ), UUID("189a3867-3050-52da-a836-e630ba90ab69") => PackageEntry(
#   name = Reexport
#   version = 1.2.2
#   tree_hash = 45e428421666073eab6f2da5c9d310d99bb12f9b
# ), UUID("864edb3b-99cc-5e75-8d2d-829cb0a9cfe8") => PackageEntry(
#   name = DataStructures
#   version = 0.18.10
#   tree_hash = 7d9d316f04214f7efdbb6398d545446e246eff02
# ), UUID("83423d85-b0ee-5818-9007-b63ccbeb887a") => PackageEntry(
#   name = Cairo_jll
#   version = 1.16.1+0
#   tree_hash = f2202b55d816427cd385a9a4f3ffb226bee80f99
# ), UUID("ade2ca70-3891-5945-98fb-dc099432e06a") => PackageEntry(
#   name = Dates
# ), UUID("731e570b-9d59-4bfa-96dc-6df516fadf69") => PackageEntry(
#   name = TiffImages
#   version = 0.5.1
#   tree_hash = 016185e1a16c1bd83a4352b19a3b136224f22e38
# ), UUID("1d5cc7b8-4909-519e-a0f8-d0f5ad9712d0") => PackageEntry(
#   name = IntelOpenMP_jll
#   version = 2018.0.3+2
#   tree_hash = d979e54b71da82f3a65b62553da4fc3d18c9004c
# ), UUID("eebad327-c553-4316-9ea0-9fa01ccd7688") => PackageEntry(
#   name = PkgVersion
#   version = 0.1.1
#   tree_hash = a7a7e1a88853564e551e4eba8650f8c38df79b37
# ), UUID("0234f1f7-429e-5d53-9886-15a909be8d59") => PackageEntry(
#   name = HDF5_jll
#   version = 1.12.0+1
#   tree_hash = fd83fa0bde42e01952757f01149dd968c06c4dba
# ), UUID("c8e1da08-722c-5040-9ed9-7db0dc04731e") => PackageEntry(
#   name = IterTools
#   version = 1.3.0
#   tree_hash = 05110a2ab1fc5f932622ffea2a003221f4782c18
# ), UUID("a09fc81d-aa75-5fe9-8630-4744c3626534") => PackageEntry(
#   name = ImageCore
#   version = 0.8.22
#   tree_hash = db645f20b59f060d8cfae696bc9538d13fd86416
# ), UUID("3bb67fe8-82b1-5028-8e26-92a6c54297fa") => PackageEntry(
#   name = TranscodingStreams
#   version = 0.9.6
#   tree_hash = 216b95ea110b5972db65aa90f88d8d89dcb8851c
# ), UUID("89763e89-9b03-5906-acba-b20f662cd828") => PackageEntry(
#   name = Libtiff_jll
#   version = 4.3.0+0
#   tree_hash = 340e257aada13f95f98ee352d316c3bed37c8ab9
# ), UUID("37e2e46d-f89d-539d-b4ee-838fcccc9c8e") => PackageEntry(
#   name = LinearAlgebra
# ), UUID("34da2185-b29b-5c13-b0c7-acf172513d20") => PackageEntry(
#   name = Compat
#   version = 3.39.0
#   tree_hash = 31d0151f5716b655421d9d75b7fa74cc4e744df2
# ), UUID("f57f5aa1-a3ce-4bc8-8ab9-96f992907883") => PackageEntry(
#   name = PNGFiles
#   version = 0.3.11
#   tree_hash = 33ae7d19c6ba748d30c0c08a82378aae7b64b5e9
# ), UUID("39de3d68-74b9-583c-8d2d-e117c070f3a9") => PackageEntry(
#   name = AxisArrays
#   version = 0.4.4
#   tree_hash = d127d5e4d86c7680b20c35d40b503c74b9a39b5e
# ), UUID("ea2cea3b-5b76-57ae-a6ef-0a8af62496e1") => PackageEntry(
#   name = Qt5Base_jll
#   version = 5.15.3+0
#   tree_hash = ad368663a5e20dbb8d6dc2fddeefe4dae0781ae8
# ), UUID("7a1cc6ca-52ef-59f5-83cd-3a7055c09341") => PackageEntry(
#   name = FFTW
#   version = 1.4.5
#   tree_hash = 463cb335fa22c4ebacfd1faba5fde14edb80d96c
# ), UUID("d4300ac3-e22c-5743-9152-c294e39db1e4") => PackageEntry(
#   name = Libgcrypt_jll
#   version = 1.8.7+0
#   tree_hash = 64613c82a59c120435c067c2b809fc61cf5166ae
# ), UUID("c3611d14-8923-5661-9e6a-0046d554d3a4") => PackageEntry(
#   name = ColorVectorSpace
#   version = 0.9.7
#   tree_hash = 45efb332df2e86f2cb2e992239b6267d97c9e0b6
# ), UUID("3da002f7-5984-5a60-b8a6-cbb66c0b333f") => PackageEntry(
#   name = ColorTypes
#   version = 0.11.0
#   tree_hash = 024fe24d83e4a5bf5fc80501a314ce0d1aa35597
# ), UUID("ec84b674-ba8e-5d96-8ba1-2a689ba10484") => PackageEntry(
#   name = Xorg_libXrandr_jll
#   version = 1.5.2+4
#   tree_hash = 34cea83cb726fb58f325887bf0612c6b3fb17631
# ), UUID("7f904dfe-b85e-4ff6-b463-dae2292396a8") => PackageEntry(
#   name = PlutoUI
#   version = 0.7.16
#   tree_hash = 4c8a7d080daca18545c56f1cac28710c362478f3
# ), UUID("0b7ba130-8d10-5ba8-a3d6-c5182647fed9") => PackageEntry(
#   name = Blosc_jll
#   version = 1.21.0+0
#   tree_hash = e747dac84f39c62aff6956651ec359686490134e
# ), UUID("4f6342f7-b3d2-589e-9d20-edeb45f2b2bc") => PackageEntry(
#   name = Xorg_libX11_jll
#   version = 1.6.9+4
#   tree_hash = 5be649d550f3f4b95308bf0183b82e2582876527
# ), UUID("de0858da-6303-5e67-8744-51eddeeeb8d7") => PackageEntry(
#   name = Printf
# ), UUID("0dad84c5-d112-42e6-8d28-ef12dabb789f") => PackageEntry(
#   name = ArgTools
# ), UUID("5ae59095-9a9b-59fe-a467-6f913c188581") => PackageEntry(
#   name = Colors
#   version = 0.12.8
#   tree_hash = 417b0ed7b8b838aa6ca0a87aadf1bb9eb111ce40
# ), UUID("cae243ae-269e-4f55-b966-ac2d0dc13c15") => PackageEntry(
#   name = StackViews
#   version = 0.1.1
#   tree_hash = 46e589465204cd0c08b4bd97385e4fa79a0c770c
# ), UUID("efe28fd5-8261-553b-a9e1-b2916fc3738e") => PackageEntry(
#   name = OpenSpecFun_jll
#   version = 0.5.5+0
#   tree_hash = 13652491f6856acfd2db29360e1bbcd4565d04f1
# ), UUID("c7cfdc94-dc32-55de-ac96-5a1b8d977c5b") => PackageEntry(
#   name = Xorg_libxcb_jll
#   version = 1.13.0+3
#   tree_hash = daf17f441228e7a3833846cd048892861cff16d6
# ), UUID("0f8b85d8-7281-11e9-16c2-39a750bddbf1") => PackageEntry(
#   name = JSON3
#   version = 1.9.2
#   tree_hash = 7d58534ffb62cd947950b3aa9b993e63307a6125
# ), UUID("c87230d0-a227-11e9-1b43-d7ebe4e7570a") => PackageEntry(
#   name = FFMPEG
#   version = 0.4.1
#   tree_hash = b57e3acbe22f8484b4b5ff66a7499717fe1a9cc8
# ), UUID("8dfed614-e22c-5e08-85e1-65c5234f0b40") => PackageEntry(
#   name = Test
# ), UUID("4e3cecfd-b093-5904-9786-8bbb286a6a31") => PackageEntry(
#   name = ImageShow
#   version = 0.3.1
#   tree_hash = 832abfd709fa436a562db47fd8e81377f72b01f9
# ), UUID("a3f928ae-7b40-5064-980b-68af3947d34b") => PackageEntry(
#   name = Fontconfig_jll
#   version = 2.13.93+0
#   tree_hash = 21efd19106a55620a188615da6d3d06cd7f6ee03
# ), UUID("5ae413db-bbd1-5e63-b57d-d24a61df00f5") => PackageEntry(
#   name = EarCut_jll
#   version = 2.2.3+0
#   tree_hash = 3f3a2501fa7236e9b911e0f7a588c657e822bb6d
# ), UUID("3587e190-3f89-42d0-90ee-14403ec27112") => PackageEntry(
#   name = InverseFunctions
#   version = 0.1.1
#   tree_hash = f0c6489b12d28fb4c2103073ec7452f3423bd308
# ), UUID("a2bd30eb-e257-5431-a919-1863eab51364") => PackageEntry(
#   name = Graphics
#   version = 1.1.1
#   tree_hash = 1c5a84319923bea76fa145d49e93aa4394c73fc2
# ), UUID("8f399da3-3557-5675-b5ff-fb832c97cbdb") => PackageEntry(
#   name = Libdl
# ), UUID("bc367c6b-8a6b-528e-b4bd-a4b897500b49") => PackageEntry(
#   name = ImageMetadata
#   version = 0.9.5
#   tree_hash = ae76038347dc4edcdb06b541595268fca65b6a42
# ), UUID("91d4177d-7536-5919-b921-800302f37372") => PackageEntry(
#   name = Opus_jll
#   version = 1.3.2+0
#   tree_hash = 51a08fb14ec28da2ec7a927c4337e4332c2a4720
# ), UUID("bac558e1-5e72-5ebc-8fee-abe8a469f55d") => PackageEntry(
#   name = OrderedCollections
#   version = 1.4.1
#   tree_hash = 85f8e6578bf1f9ee0d11e7bb1b1456435479d47c
# ), UUID("83e8ac13-25f8-5344-8a64-a9f2b223428f") => PackageEntry(
#   name = IniFile
#   version = 0.5.0
#   tree_hash = 098e4d2c533924c921f9f9847274f2ad89e018b8
# ), UUID("7e76a0d4-f3c7-5321-8279-8d96eeed0f29") => PackageEntry(
#   name = Libglvnd_jll
#   version = 1.3.0+3
#   tree_hash = 7739f837d6447403596a75d19ed01fd08d6f56bf
# ), UUID("b4f34e82-e78d-54a5-968a-f98e89d6e8f7") => PackageEntry(
#   name = Distances
#   version = 0.10.5
#   tree_hash = 09d9eaef9ef719d2cd5d928a191dc95be2ec8059
# ), UUID("b77e0a4c-d291-57a0-90e8-8db25a27a240") => PackageEntry(
#   name = InteractiveUtils
# ), UUID("e66e0078-7015-5450-92f7-15fbd957f2ae") => PackageEntry(
#   name = CompilerSupportLibraries_jll
# ), UUID("6c6a2e73-6563-6170-7368-637461726353") => PackageEntry(
#   name = Scratch
#   version = 1.1.0
#   tree_hash = 0b4b7f1393cff97c33891da2a0bf69c6ed241fda
# ), UUID("56ddb016-857b-54e1-b83d-db4d58db5568") => PackageEntry(
#   name = Logging
# ), UUID("82899510-4779-5014-852e-03e436cf321d") => PackageEntry(
#   name = IteratorInterfaceExtensions
#   version = 1.0.0
#   tree_hash = a3f24677c21f5bbe9d2a714f95dcd58337fb2856
# ), UUID("1914dd2f-81c6-5fcd-8719-6d5c9610ff09") => PackageEntry(
#   name = MacroTools
#   version = 0.5.8
#   tree_hash = 5a5bc6bf062f0f95e62d0fe0a2d99699fed82dd9
# ), UUID("7add5ba3-2f88-524e-9cd5-f83b8a55f7b8") => PackageEntry(
#   name = Libgpg_error_jll
#   version = 1.42.0+0
#   tree_hash = c333716e46366857753e273ce6a69ee0945a6db9
# ), UUID("56f22d72-fd6d-98f1-02f0-08ddc0907c33") => PackageEntry(
#   name = Artifacts
# ), UUID("02c8fc9c-b97f-50b9-bbe4-9be30ff0a78a") => PackageEntry(
#   name = XML2_jll
#   version = 2.9.12+0
#   tree_hash = 1acf5bdf07aa0907e0a37d3718bb88d4b687b74a
# ), UUID("2e619515-83b5-522b-bb60-26c02a35a201") => PackageEntry(
#   name = Expat_jll
#   version = 2.2.10+0
#   tree_hash = b3bfd02e98aedfa5cf885665493c5598c350cd2f
# ), UUID("6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf") => PackageEntry(
#   name = BenchmarkTools
#   version = 1.2.0
#   tree_hash = 61adeb0823084487000600ef8b1c00cc2474cd47
# ), UUID("f332f351-ec65-5f6a-b3d1-319c6670881a") => PackageEntry(
#   name = ImageContrastAdjustment
#   version = 0.3.7
#   tree_hash = 2e6084db6cccab11fe0bc3e4130bd3d117092ed9
# ), UUID("44cfe95a-1eb2-52ea-b672-e2afdf69b78f") => PackageEntry(
#   name = Pkg
# ), UUID("787d08f9-d448-5407-9aad-5290dd7ab264") => PackageEntry(
#   name = ImageMorphology
#   version = 0.2.11
#   tree_hash = 68e7cbcd7dfaa3c2f74b0a8ab3066f5de8f2b71d
# ), UUID("ae029012-a4dd-5104-9daa-d747884805df") => PackageEntry(
#   name = Requires
#   version = 1.1.3
#   tree_hash = 4036a3bd08ac7e968e27c203d45f5fff15020621
# ), UUID("23992714-dd62-5051-b70f-ba57cb901cac") => PackageEntry(
#   name = MAT
#   version = 0.10.1
#   tree_hash = 5c62992f3d46b8dce69bdd234279bb5a369db7d5
# ), UUID("10745b16-79ce-11e8-11f9-7d13ad32a3b2") => PackageEntry(
#   name = Statistics
# ), UUID("aacddb02-875f-59d6-b918-886e6ef4fbf8") => PackageEntry(
#   name = JpegTurbo_jll
#   version = 2.1.0+0
#   tree_hash = d735490ac75c5cb9f1b00d8b5509c11984dc6943
# ), UUID("91a5bcdd-55d7-5caf-9e0b-520d859cae80") => PackageEntry(
#   name = Plots
#   version = 1.23.1
#   tree_hash = 25007065fa36f272661a0e1968761858cc880755
# ), UUID("62fd8b95-f654-4bbd-a8a5-9c27f68ccd50") => PackageEntry(
#   name = TensorCore
#   version = 0.1.1
#   tree_hash = 1feb45f88d133a655e001435632f019a9a1bcdb6
# ), UUID("1a1011a3-84de-559e-8e89-a11a2f7dc383") => PackageEntry(
#   name = SharedArrays
# ), UUID("d091e8ba-531a-589c-9de9-94069b037ed8") => PackageEntry(
#   name = Xorg_libXfixes_jll
#   version = 5.0.3+4
#   tree_hash = 0e0dc7431e7a0587559f9294aeec269471c991a4
# ), UUID("692b3bcd-3c85-4b1f-b108-f13ce0eb3210") => PackageEntry(
#   name = JLLWrappers
#   version = 1.3.0
#   tree_hash = 642a199af8b68253517b80bd3bfd17eb4e84df6e
# ), UUID("4f61f5a4-77b1-5117-aa51-3ab5ef4ef0cd") => PackageEntry(
#   name = FFTViews
#   version = 0.3.2
#   tree_hash = cbdf14d1e8c7c8aacbe8b19862e0179fd08321c2
# ), UUID("276daf66-3868-5448-9aa4-cd146d93841b") => PackageEntry(
#   name = SpecialFunctions
#   version = 1.8.1
#   tree_hash = f0bccf98e16759818ffc5d97ac3ebf87eb950150
# ), UUID("94ce4f54-9a6c-5748-9c1c-f9c7231a4531") => PackageEntry(
#   name = Libiconv_jll
#   version = 1.16.1+1
#   tree_hash = 42b62845d70a619f063a7da093d995ec8e15e778
# ), UUID("ccf2f8ad-2431-5c83-bf29-c5338b663b6a") => PackageEntry(
#   name = PlotThemes
#   version = 2.0.1
#   tree_hash = a3a964ce9dc7898193536002a6dd892b1b5a6f1d
# ), UUID("30392449-352a-5448-841d-b1acce4e97dc") => PackageEntry(
#   name = Pixman_jll
#   version = 0.40.1+0
#   tree_hash = b4f5d02549a10e20780a24fce72bea96b6329e29
# ), UUID("deac9b47-8bc7-5906-a0fe-35ac56dc84c0") => PackageEntry(
#   name = LibCURL_jll
# ), UUID("fa961155-64e5-5f13-b03f-caf6b980ea82") => PackageEntry(
#   name = CEnum
#   version = 0.4.1
#   tree_hash = 215a9aa4a1f23fbd05b92769fdd62559488d70e9
# ), UUID("e1450e63-4bb3-523b-b2a4-4ffa8c0fd77d") => PackageEntry(
#   name = BufferedStreams
#   version = 1.0.0
#   tree_hash = 5d55b9486590fdda5905c275bb21ce1f0754020f
# ), UUID("a3789734-cfe1-5b06-b2d0-1dd0d9d62d05") => PackageEntry(
#   name = Xorg_libXdmcp_jll
#   version = 1.1.3+4
#   tree_hash = 4fe47bd2247248125c428978740e18a681372dd4
# )), Dict{String, Any}()), Pkg.Types.Project(Dict{String, Any}("deps" => Dict{String, Any}("MLDatasets" => "eb30cadb-4394-5ae3-aed4-317e484a6458", "Images" => "916415d5-f1e6-5110-898d-aaa5f9f070e0", "PlutoUI" => "7f904dfe-b85e-4ff6-b463-dae2292396a8", "Plots" => "91a5bcdd-55d7-5caf-9e0b-520d859cae80", "BenchmarkTools" => "6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf", "TestImages" => "5e47fb64-e119-507b-a336-dd2b206d9990"), "compat" => Dict{String, Any}("MLDatasets" => "~0.5.12", "Images" => "~0.24.1", "PlutoUI" => "~0.7.16", "Plots" => "~1.23.1", "BenchmarkTools" => "~1.2.0", "TestImages" => "~1.6.2")), nothing, nothing, nothing, nothing, Dict{String, Base.UUID}("MLDatasets" => UUID("eb30cadb-4394-5ae3-aed4-317e484a6458"), "Images" => UUID("916415d5-f1e6-5110-898d-aaa5f9f070e0"), "PlutoUI" => UUID("7f904dfe-b85e-4ff6-b463-dae2292396a8"), "Plots" => UUID("91a5bcdd-55d7-5caf-9e0b-520d859cae80"), "BenchmarkTools" => UUID("6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf"), "TestImages" => UUID("5e47fb64-e119-507b-a336-dd2b206d9990")), Dict{String, Base.UUID}(), Dict{String, Vector{String}}(), Dict("MLDatasets" => "~0.5.12", "Images" => "~0.24.1", "PlutoUI" => "~0.7.16", "Plots" => "~1.23.1", "BenchmarkTools" => "~1.2.0", "TestImages" => "~1.6.2")), Pkg.Types.Manifest(v"1.7.0-rc2", v"2.0.0", Dict{Base.UUID, Pkg.Types.PackageEntry}(UUID("69de0a69-1ddd-5017-9359-2bf0b02dc9f0") => PackageEntry(
#   name = Parsers
#   version = 2.1.1
#   tree_hash = d911b6a12ba974dabe2291c6d450094a7226b372
# ), UUID("5ced341a-0733-55b8-9ab6-a4889d929147") => PackageEntry(
#   name = Lz4_jll
#   version = 1.9.3+0
#   tree_hash = 5d494bc6e85c4c9b626ee0cab05daa4085486ab1
# ), UUID("d7e528f0-a631-5988-bf34-fe36492bcfd7") => PackageEntry(
#   name = FreeType2_jll
#   version = 2.10.4+0
#   tree_hash = 87eb71354d8ec1a96d4a7636bd57a7347dde3ef9
# ), UUID("c8ffd9c3-330d-5841-b78e-0817d7145fa1") => PackageEntry(
#   name = MbedTLS_jll
# ), UUID("4b2f31a3-9ecc-558c-b454-b3730dcb73e9") => PackageEntry(
#   name = Libmount_jll
#   version = 2.35.0+0
#   tree_hash = 9c30530bf0effd46e15e0fdcf2b8636e78cbbd73
# ), UUID("82ae8749-77ed-4fe6-ae5f-f523153014b0") => PackageEntry(
#   name = StatsAPI
#   version = 1.0.0
#   tree_hash = 1958272568dc176a1d881acb797beb909c785510
# ), UUID("ed09eef8-17a6-5b46-8889-db040fac31e3") => PackageEntry(
#   name = ComputationalResources
#   version = 0.3.2
#   tree_hash = 52cb3ec90e8a8bea0e62e275ba577ad0f74821f7
# ), UUID("9e28174c-4ba2-5203-b857-d8d62c4213ee") => PackageEntry(
#   name = BinDeps
#   version = 1.0.2
#   tree_hash = 1289b57e8cf019aede076edab0587eb9644175bd
# ), UUID("30578b45-9adc-5946-b283-645ec420af67") => PackageEntry(
#   name = URIParser
#   version = 0.4.1
#   tree_hash = 53a9f49546b8d2dd2e688d216421d050c9a31d0d
# ), UUID("6218d12a-5da1-5696-b52f-db25d2ecc6d1") => PackageEntry(
#   name = ImageMagick
#   version = 1.2.1
#   tree_hash = 5bc1cb62e0c5f1005868358db0692c994c3a13c6
# ), UUID("dbb5928d-eab1-5f90-85c2-b9b0edb7c900") => PackageEntry(
#   name = MappedArrays
#   version = 0.4.1
#   tree_hash = e8b359ef06ec72e8c030463fe02efe5527ee5142
# ), UUID("9a3f8284-a2c9-5f02-9a11-845980a1fd5c") => PackageEntry(
#   name = Random
# ), UUID("4fba245c-0d91-5ea0-9b3e-6abc04ee57a9") => PackageEntry(
#   name = ArrayInterface
#   version = 3.1.36
#   tree_hash = a8101545d6b15ff1ebc927e877e28b0ab4bc4f16
# ), UUID("8bb1440f-4735-579b-a4ab-409b98df4dab") => PackageEntry(
#   name = DelimitedFiles
# ), UUID("82e4d734-157c-48bb-816b-45c225c6df19") => PackageEntry(
#   name = ImageIO
#   version = 0.5.9
#   tree_hash = a2951c93684551467265e0e32b577914f69532be
# ), UUID("9e88b42a-f829-5b0c-bbe9-9e923198166b") => PackageEntry(
#   name = Serialization
# ), UUID("aed1982a-8fda-507f-9586-7b0439959a61") => PackageEntry(
#   name = XSLT_jll
#   version = 1.1.34+0
#   tree_hash = 91844873c4085240b95e795f692c4cec4d805f8a
# ), UUID("699a6c99-e7fa-54fc-8d76-47d257e15c1d") => PackageEntry(
#   name = SimpleTraits
#   version = 0.9.4
#   tree_hash = 5d7e3f4e11935503d3ecaf7186eac40602e7d231
# ), UUID("bd369af6-aec1-5ad0-b16a-f7cc5008161c") => PackageEntry(
#   name = Tables
#   version = 1.6.0
#   tree_hash = fed34d0e71b91734bf0a7e10eb1bb05296ddbcd0
# ), UUID("3783bdb8-4a98-5b6b-af9a-565f29a5fe9c") => PackageEntry(
#   name = TableTraits
#   version = 1.0.1
#   tree_hash = c06b2f539df1c6efa794486abfb6ed2022561a39
# ), UUID("f09324ee-3d7c-5217-9330-fc30815ba969") => PackageEntry(
#   name = Netpbm
#   version = 1.0.1
#   tree_hash = 09589171688f0039f13ebe0fdcc7288f50228b52
# ), UUID("51556ac3-7006-55f5-8cb3-34580c88182d") => PackageEntry(
#   name = ImageDistances
#   version = 0.2.13
#   tree_hash = 6378c34a3c3a216235210d19b9f495ecfff2f85f
# ), UUID("bbac6d45-d8f3-5730-bfe4-7a449cd117ca") => PackageEntry(
#   name = IdentityRanges
#   version = 0.3.1
#   tree_hash = be8fcd695c4da16a1d6d0cd213cb88090a150e3b
# ), UUID("0d47668e-0667-5a69-a72c-f761630bfb7e") => PackageEntry(
#   name = Xorg_xcb_util_renderutil_jll
#   version = 0.3.9+1
#   tree_hash = dfd7a8f38d4613b6a575253b3174dd991ca6183e
# ), UUID("739be429-bea8-5141-9913-cc70e7f3736d") => PackageEntry(
#   name = MbedTLS
#   version = 1.0.3
#   tree_hash = 1c38e51c3d08ef2278062ebceade0e46cefc96fe
# ), UUID("b27032c2-a3e7-50c8-80cd-2d36dbcbfd21") => PackageEntry(
#   name = LibCURL
# ), UUID("150eb455-5306-5404-9cee-2592286d6298") => PackageEntry(
#   name = CoordinateTransformations
#   version = 0.6.1
#   tree_hash = 6d1c23e740a586955645500bbec662476204a52c
# ), UUID("01d81517-befc-4cb6-b9ec-a95719d0359c") => PackageEntry(
#   name = RecipesPipeline
#   version = 0.4.1
#   tree_hash = 7ad0dfa8d03b7bcf8c597f59f5292801730c55b8
# ), UUID("2996bd0c-7a13-11e9-2da2-2f5ce47296a9") => PackageEntry(
#   name = ImageQualityIndexes
#   version = 0.2.2
#   tree_hash = 1198f85fa2481a3bb94bf937495ba1916f12b533
# ), UUID("83775a58-1f1d-513f-b197-d71354ab007a") => PackageEntry(
#   name = Zlib_jll
# ), UUID("02fcd773-0e25-5acc-982a-7f6622650795") => PackageEntry(
#   name = ImageTransformations
#   version = 0.8.13
#   tree_hash = e4cc551e4295a5c96545bb3083058c24b78d4cf0
# ), UUID("7746bdde-850d-59dc-9ae8-88ece973131d") => PackageEntry(
#   name = Glib_jll
#   version = 2.68.3+0
#   tree_hash = 7bf67e9a481712b3dbe9cb3dac852dc4b1162e02
# ), UUID("76f85450-5226-5b5a-8eaa-529ad045b433") => PackageEntry(
#   name = LibGit2
# ), UUID("e94cdb99-869f-56ef-bcf0-1ae2bcbe0389") => PackageEntry(
#   name = MosaicViews
#   version = 0.3.3
#   tree_hash = b34e3bc3ca7c94914418637cb10cc4d1d80d877d
# ), UUID("77ba4419-2d1f-58cd-9bb1-8ffee604a2e3") => PackageEntry(
#   name = NaNMath
#   version = 0.3.5
#   tree_hash = bfe47e760d60b82b66b61d2d44128b62e3a369fb
# ), UUID("3b182d85-2403-5c21-9c21-1e1f0cc25472") => PackageEntry(
#   name = Graphite2_jll
#   version = 1.3.14+0
#   tree_hash = 344bf40dcab1073aca04aa0df4fb092f920e4011
# ), UUID("9b13fd28-a010-5f03-acff-a1bbcff69959") => PackageEntry(
#   name = IndirectArrays
#   version = 0.5.1
#   tree_hash = c2a145a145dc03a7620af1444e0264ef907bd44f
# ), UUID("2913bbd2-ae8a-5f71-8c99-4fb6c76f3a91") => PackageEntry(
#   name = StatsBase
#   version = 0.33.12
#   tree_hash = eb35dcc66558b2dda84079b9a1be17557d32091a
# ), UUID("d38c429a-6771-53c6-b99e-75d170b6e991") => PackageEntry(
#   name = Contour
#   version = 0.5.7
#   tree_hash = 9f02045d934dc030edad45944ea80dbd1f0ebea7
# ), UUID("a2964d1f-97da-50d4-b82a-358c7fce9d89") => PackageEntry(
#   name = Wayland_jll
#   version = 1.19.0+0
#   tree_hash = 3e61f0b86f90dacb0bc0e73a0c5a83f6a8636e23
# ), UUID("b22a6f82-2f65-5046-a5b2-351ab43fb4e5") => PackageEntry(
#   name = FFMPEG_jll
#   version = 4.4.0+0
#   tree_hash = d8a578692e3077ac998b50c0217dfd67f21d1e5f
# ), UUID("dfaa095f-4041-5dcd-9319-2fabd8486b76") => PackageEntry(
#   name = x265_jll
#   version = 3.5.0+0
#   tree_hash = ee567a171cce03570d77ad3a43e90218e38937a9
# ), UUID("e2d170a0-9d28-54be-80f0-106bbe20a464") => PackageEntry(
#   name = DataValueInterfaces
#   version = 1.0.0
#   tree_hash = bfc1187b79289637fa0ef6d4436ebdfe6905cbd6
# ), UUID("6e34b625-4abd-537c-b88f-471c36dfa7a0") => PackageEntry(
#   name = Bzip2_jll
#   version = 1.0.8+0
#   tree_hash = 19a35467a82e236ff51bc17a3a44b69ef35185a2
# ), UUID("621f4979-c628-5d54-868e-fcf4e3e8185c") => PackageEntry(
#   name = AbstractFFTs
#   version = 1.0.1
#   tree_hash = 485ee0867925449198280d4af84bdb46a2a404d0
# ), UUID("35d6a980-a343-548e-a6ea-1d62b119f2f4") => PackageEntry(
#   name = ColorSchemes
#   version = 3.15.0
#   tree_hash = a851fec56cb73cfdf43762999ec72eff5b86882a
# ), UUID("cf7118a7-6976-5b1a-9a39-7adc72f591a4") => PackageEntry(
#   name = UUIDs
# ), UUID("dc8bdbbb-1ca9-579f-8c36-e416f6a65cce") => PackageEntry(
#   name = CustomUnitRanges
#   version = 1.0.2
#   tree_hash = 1a3f97f907e6dd8983b744d2642651bb162a3f7a
# ), UUID("2381bf8a-dfd0-557d-9999-79630e7b1b91") => PackageEntry(
#   name = Wayland_protocols_jll
#   version = 1.18.0+4
#   tree_hash = 2839f1c1296940218e35df0bbb220f2a79686670
# ), UUID("06e1c1a7-607b-532d-9fad-de7d9aa2abac") => PackageEntry(
#   name = TiledIteration
#   version = 0.3.1
#   tree_hash = 5683455224ba92ef59db72d10690690f4a8dc297
# ...
#   name = MAT
#   version = 0.10.1
#   tree_hash = 5c62992f3d46b8dce69bdd234279bb5a369db7d5
# ), UUID("10745b16-79ce-11e8-11f9-7d13ad32a3b2") => PackageEntry(
#   name = Statistics
# ), UUID("aacddb02-875f-59d6-b918-886e6ef4fbf8") => PackageEntry(
#   name = JpegTurbo_jll
#   version = 2.1.0+0
#   tree_hash = d735490ac75c5cb9f1b00d8b5509c11984dc6943
# ), UUID("91a5bcdd-55d7-5caf-9e0b-520d859cae80") => PackageEntry(
#   name = Plots
#   version = 1.23.1
#   tree_hash = 25007065fa36f272661a0e1968761858cc880755
# ), UUID("62fd8b95-f654-4bbd-a8a5-9c27f68ccd50") => PackageEntry(
#   name = TensorCore
#   version = 0.1.1
#   tree_hash = 1feb45f88d133a655e001435632f019a9a1bcdb6
# ), UUID("1a1011a3-84de-559e-8e89-a11a2f7dc383") => PackageEntry(
#   name = SharedArrays
# ), UUID("d091e8ba-531a-589c-9de9-94069b037ed8") => PackageEntry(
#   name = Xorg_libXfixes_jll
#   version = 5.0.3+4
#   tree_hash = 0e0dc7431e7a0587559f9294aeec269471c991a4
# ), UUID("692b3bcd-3c85-4b1f-b108-f13ce0eb3210") => PackageEntry(
#   name = JLLWrappers
#   version = 1.3.0
#   tree_hash = 642a199af8b68253517b80bd3bfd17eb4e84df6e
# ), UUID("4f61f5a4-77b1-5117-aa51-3ab5ef4ef0cd") => PackageEntry(
#   name = FFTViews
#   version = 0.3.2
#   tree_hash = cbdf14d1e8c7c8aacbe8b19862e0179fd08321c2
# ), UUID("276daf66-3868-5448-9aa4-cd146d93841b") => PackageEntry(
#   name = SpecialFunctions
#   version = 1.8.1
#   tree_hash = f0bccf98e16759818ffc5d97ac3ebf87eb950150
# ), UUID("94ce4f54-9a6c-5748-9c1c-f9c7231a4531") => PackageEntry(
#   name = Libiconv_jll
#   version = 1.16.1+1
#   tree_hash = 42b62845d70a619f063a7da093d995ec8e15e778
# ), UUID("ccf2f8ad-2431-5c83-bf29-c5338b663b6a") => PackageEntry(
#   name = PlotThemes
#   version = 2.0.1
#   tree_hash = a3a964ce9dc7898193536002a6dd892b1b5a6f1d
# ), UUID("30392449-352a-5448-841d-b1acce4e97dc") => PackageEntry(
#   name = Pixman_jll
#   version = 0.40.1+0
#   tree_hash = b4f5d02549a10e20780a24fce72bea96b6329e29
# ), UUID("deac9b47-8bc7-5906-a0fe-35ac56dc84c0") => PackageEntry(
#   name = LibCURL_jll
# ), UUID("fa961155-64e5-5f13-b03f-caf6b980ea82") => PackageEntry(
#   name = CEnum
#   version = 0.4.1
#   tree_hash = 215a9aa4a1f23fbd05b92769fdd62559488d70e9
# ), UUID("e1450e63-4bb3-523b-b2a4-4ffa8c0fd77d") => PackageEntry(
#   name = BufferedStreams
#   version = 1.0.0
#   tree_hash = 5d55b9486590fdda5905c275bb21ce1f0754020f
# ), UUID("a3789734-cfe1-5b06-b2d0-1dd0d9d62d05") => PackageEntry(
#   name = Xorg_libXdmcp_jll
#   version = 1.1.3+4
#   tree_hash = 4fe47bd2247248125c428978740e18a681372dd4
# )), Dict{String, Any}()), Dict{String, Vector{Base.UUID}}(), Dict{Base.UUID, Vector{String}}(), Dict{Base.UUID, Vector{String}}()), IJulia.IJuliaStdio{Base.PipeEndpoint}(IOContext(Base.PipeEndpoint(Base.Libc.WindowsRawSocket(0x00000000000002d4) open, 0 bytes waiting))), false, false, 8, false, v"1.6.2", nothing, Base.TOML.Parser("", '\xff\xff\xff\xff', 1, 1, 1, 1, 0, Dict{String, Any}(), String[], UnitRange{Int64}[], Base.IdSet{Dict{String, Any}}(IdDict{Dict{String, Any}, Nothing}()), Base.IdSet{Any}(IdDict{Any, Nothing}()), Base.IdSet{Dict{String, Any}}(IdDict{Dict{String, Any}, Nothing}()), Dict{String, Any}(), nothing, Dates)), nothing), 0x00000000000073fe), Union{Ptr{Nothing}, Base.InterpreterIP}[Ptr{Nothing} @0x00000000025ef324, Ptr{Nothing} @0x00000000025f49fa, Ptr{Nothing} @0x00000000025f5218, Ptr{Nothing} @0x00000000025f8630, Ptr{Nothing} @0x0000000000d9cdbe, Ptr{Nothing} @0x0000000000d9dc03, Ptr{Nothing} @0x0000000000d9e09b, Ptr{Nothing} @0x0000000000d9e63c, Ptr{Nothing} @0x0000000000d9e9a9, Ptr{Nothing} @0x0000000000d9ebac, Ptr{Nothing} @0x0000000000d9eebd, Ptr{Nothing} @0x0000000000da252b, Ptr{Nothing} @0x0000000000da3b3c, Ptr{Nothing} @0x0000000000d8d53c, Ptr{Nothing} @0x0000000000d99985, Ptr{Nothing} @0x0000000000d99fdc, Ptr{Nothing} @0x000000001f0cbbc9])
# └ @ Pluto.PkgCompat C:\Users\james\.julia\packages\Pluto\MfWSf\src\packages\PkgCompat.jl:335
# ┌ Warning: Failed to resolve Pkg environment. Removing Manifest and trying again...
# │   exception = ErrorException("could not find entry with uuid 8e850b90-86db-534c-a0d3-1478176c7d93 in manifest C:\\Users\\james\\AppData\\Local\\Temp\\jl_LHaOOw\\Manifest.toml")
# └ @ Pluto C:\Users\james\.julia\packages\Pluto\MfWSf\src\packages\Packages.jl:113
#    Installed IfElse ──────────────────── v0.1.1
#    Installed CoordinateTransformations ─ v0.6.2
#    Installed GR_jll ──────────────────── v0.62.0+0
#    Installed MacroTools ──────────────── v0.5.9
#    Installed Compat ──────────────────── v3.40.0
#    Installed Plots ───────────────────── v1.23.2
#    Installed ArrayInterface ──────────── v3.1.38
#    Installed Distances ───────────────── v0.10.6
#    Installed FileIO ──────────────────── v1.11.2
#     Updating `C:\Users\james\AppData\Local\Temp\jl_LHaOOw\Project.toml`
#   [6e4b80f9] + BenchmarkTools v1.2.0
#   [916415d5] + Images v0.24.1
#   [eb30cadb] + MLDatasets v0.5.12
#   [91a5bcdd] + Plots v1.23.2
#   [7f904dfe] + PlutoUI v0.7.16
#   [5e47fb64] + TestImages v1.6.2
#     Updating `C:\Users\james\AppData\Local\Temp\jl_LHaOOw\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.0.1
#   [79e6a3ab] + Adapt v3.3.1
#   [4fba245c] + ArrayInterface v3.1.38
#   [13072b0f] + AxisAlgorithms v1.0.1
#   [39de3d68] + AxisArrays v0.4.4
#   [6e4b80f9] + BenchmarkTools v1.2.0
#   [9e28174c] + BinDeps v1.0.2
#   [b99e7846] + BinaryProvider v0.5.10
#   [a74b3585] + Blosc v0.7.1
#   [e1450e63] + BufferedStreams v1.0.0
#   [fa961155] + CEnum v0.4.1
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] + ChainRulesCore v1.11.0
#   [944b1d66] + CodecZlib v0.7.0
#   [35d6a980] + ColorSchemes v3.15.0
#   [3da002f7] + ColorTypes v0.11.0
#   [c3611d14] + ColorVectorSpace v0.9.7
#   [5ae59095] + Colors v0.12.8
#   [34da2185] + Compat v3.40.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [8f4d0f93] + Conda v1.5.2
#   [d38c429a] + Contour v0.5.7
#   [150eb455] + CoordinateTransformations v0.6.2
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [9a962f9c] + DataAPI v1.9.0
#   [124859b0] + DataDeps v0.7.7
#   [864edb3b] + DataStructures v0.18.10
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [b4f34e82] + Distances v0.10.6
#   [ffbed154] + DocStringExtensions v0.8.6
#   [da5c29d0] + EllipsisNotation v1.1.0
#   [c87230d0] + FFMPEG v0.4.1
#   [4f61f5a4] + FFTViews v0.3.2
#   [7a1cc6ca] + FFTW v1.4.5
#   [5789e2e9] + FileIO v1.11.2
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [59287772] + Formatting v0.4.2
#   [28b8d3ca] + GR v0.61.0
#   [92fee26a] + GZip v0.5.1
#   [5c1252a2] + GeometryBasics v0.4.1
#   [a2bd30eb] + Graphics v1.1.1
#   [42e2da0e] + Grisu v1.0.2
#   [f67ccb44] + HDF5 v0.15.7
#   [cd3eb016] + HTTP v0.9.16
#   [47d2ed2b] + Hyperscript v0.0.4
#   [ac1192a8] + HypertextLiteral v0.9.2
#   [b5f81e59] + IOCapture v0.2.2
#   [bbac6d45] + IdentityRanges v0.3.1
#   [615f187c] + IfElse v0.1.1
#   [2803e5a7] + ImageAxes v0.6.9
#   [f332f351] + ImageContrastAdjustment v0.3.7
#   [a09fc81d] + ImageCore v0.8.22
#   [51556ac3] + ImageDistances v0.2.13
#   [6a3955dd] + ImageFiltering v0.6.21
#   [82e4d734] + ImageIO v0.5.9
#   [6218d12a] + ImageMagick v1.2.1
#   [bc367c6b] + ImageMetadata v0.9.5
#   [787d08f9] + ImageMorphology v0.2.11
#   [2996bd0c] + ImageQualityIndexes v0.2.2
#   [4e3cecfd] + ImageShow v0.3.1
#   [02fcd773] + ImageTransformations v0.8.13
#   [916415d5] + Images v0.24.1
#   [9b13fd28] + IndirectArrays v0.5.1
#   [d25df0c9] + Inflate v0.1.2
#   [83e8ac13] + IniFile v0.5.0
#   [a98d9a8b] + Interpolations v0.13.4
#   [8197267c] + IntervalSets v0.5.3
#   [3587e190] + InverseFunctions v0.1.1
#   [92d709cd] + IrrationalConstants v0.1.1
#   [c8e1da08] + IterTools v1.3.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [692b3bcd] + JLLWrappers v1.3.0
#   [682c06a0] + JSON v0.21.2
#   [0f8b85d8] + JSON3 v1.9.2
#   [b964fa9f] + LaTeXStrings v1.2.1
#   [23fbe1c1] + Latexify v0.15.9
#   [2ab3a3ac] + LogExpFunctions v0.3.4
#   [23992714] + MAT v0.10.1
#   [eb30cadb] + MLDatasets v0.5.12
#   [1914dd2f] + MacroTools v0.5.9
#   [dbb5928d] + MappedArrays v0.4.1
#   [739be429] + MbedTLS v1.0.3
#   [442fdcdd] + Measures v0.3.1
#   [e1d29d7a] + Missings v1.0.2
#   [e94cdb99] + MosaicViews v0.3.3
#   [77ba4419] + NaNMath v0.3.5
#   [f09324ee] + Netpbm v1.0.1
#   [6fe1bfb0] + OffsetArrays v1.10.7
#   [52e1d378] + OpenEXR v0.3.2
#   [bac558e1] + OrderedCollections v1.4.1
#   [f57f5aa1] + PNGFiles v0.3.11
#   [5432bcbf] + PaddedViews v0.5.10
#   [d96e819e] + Parameters v0.12.3
#   [69de0a69] + Parsers v2.1.1
#   [eebad327] + PkgVersion v0.1.1
#   [ccf2f8ad] + PlotThemes v2.0.1
#   [995b91a9] + PlotUtils v1.0.15
#   [91a5bcdd] + Plots v1.23.2
#   [7f904dfe] + PlutoUI v0.7.16
#   [21216c6a] + Preferences v1.2.2
#   [92933f4c] + ProgressMeter v1.7.1
#   [438e738f] + PyCall v1.92.5
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c84ed2f1] + Ratios v0.4.2
#   [3cdcf5f2] + RecipesBase v1.1.2
#   [01d81517] + RecipesPipeline v0.4.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.1.3
#   [6038ab10] + Rotations v1.0.3
#   [6c6a2e73] + Scratch v1.1.0
#   [992d4aef] + Showoff v1.0.3
#   [699a6c99] + SimpleTraits v0.9.4
#   [a2af1166] + SortingAlgorithms v1.0.1
#   [276daf66] + SpecialFunctions v1.8.1
#   [cae243ae] + StackViews v0.1.1
#   [aedffcd0] + Static v0.4.0
#   [90137ffa] + StaticArrays v1.2.13
#   [82ae8749] + StatsAPI v1.0.0
#   [2913bbd2] + StatsBase v0.33.12
#   [88034a9c] + StringDistances v0.11.1
#   [09ab397b] + StructArrays v0.6.3
#   [856f2bd8] + StructTypes v1.8.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.6.0
#   [62fd8b95] + TensorCore v0.1.1
#   [5e47fb64] + TestImages v1.6.2
#   [731e570b] + TiffImages v0.5.1
#   [06e1c1a7] + TiledIteration v0.3.1
#   [3bb67fe8] + TranscodingStreams v0.9.6
#   [30578b45] + URIParser v0.4.1
#   [5c2747f8] + URIs v1.3.0
#   [3a884ed6] + UnPack v1.0.2
#   [81def892] + VersionParsing v1.2.1
#   [efce3f68] + WoodburyMatrices v0.5.5
#   [0b7ba130] + Blosc_jll v1.21.0+0
#   [6e34b625] + Bzip2_jll v1.0.8+0
#   [83423d85] + Cairo_jll v1.16.1+0
#   [5ae413db] + EarCut_jll v2.2.3+0
#   [2e619515] + Expat_jll v2.2.10+0
#   [b22a6f82] + FFMPEG_jll v4.4.0+0
#   [f5851436] + FFTW_jll v3.3.10+0
#   [a3f928ae] + Fontconfig_jll v2.13.93+0
#   [d7e528f0] + FreeType2_jll v2.10.4+0
#   [559328eb] + FriBidi_jll v1.0.10+0
#   [0656b61e] + GLFW_jll v3.3.5+1
#   [d2c73de3] + GR_jll v0.62.0+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.68.3+0
#   [3b182d85] + Graphite2_jll v1.3.14+0
#   [0234f1f7] + HDF5_jll v1.12.0+1
#   [2e76f6c2] + HarfBuzz_jll v2.8.1+0
#   [c73af94c] + ImageMagick_jll v6.9.12+0
#   [905a6f67] + Imath_jll v3.1.2+0
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [aacddb02] + JpegTurbo_jll v2.1.0+0
#   [c1c5ebd0] + LAME_jll v3.100.1+0
#   [dd4b983a] + LZO_jll v2.10.1+0
#   [e9f186c6] + Libffi_jll v3.2.2+0
#   [d4300ac3] + Libgcrypt_jll v1.8.7+0
#   [7e76a0d4] + Libglvnd_jll v1.3.0+3
#   [7add5ba3] + Libgpg_error_jll v1.42.0+0
#   [94ce4f54] + Libiconv_jll v1.16.1+1
#   [4b2f31a3] + Libmount_jll v2.35.0+0
#   [89763e89] + Libtiff_jll v4.3.0+0
#   [38a345b3] + Libuuid_jll v2.36.0+0
#   [5ced341a] + Lz4_jll v1.9.3+0
#   [856f044c] + MKL_jll v2021.1.1+2
#   [e7412a2a] + Ogg_jll v1.3.5+0
#   [18a262bb] + OpenEXR_jll v3.1.1+0
#   [458c3c95] + OpenSSL_jll v1.1.10+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [91d4177d] + Opus_jll v1.3.2+0
#   [2f80f16e] + PCRE_jll v8.44.0+0
#   [30392449] + Pixman_jll v0.40.1+0
#   [ea2cea3b] + Qt5Base_jll v5.15.3+0
#   [a2964d1f] + Wayland_jll v1.19.0+0
#   [2381bf8a] + Wayland_protocols_jll v1.18.0+4
#   [02c8fc9c] + XML2_jll v2.9.12+0
#   [aed1982a] + XSLT_jll v1.1.34+0
#   [4f6342f7] + Xorg_libX11_jll v1.6.9+4
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.9+4
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.3+4
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.0+3
#   [c7cfdc94] + Xorg_libxcb_jll v1.13.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.0+4
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.2+4
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.27.0+4
#   [c5fb5394] + Xorg_xtrans_jll v1.4.0+3
#   [3161d3a3] + Zstd_jll v1.5.0+0
#   [0ac62f75] + libass_jll v0.15.1+0
#   [f638f0a6] + libfdk_aac_jll v2.0.2+0
#   [b53b4c65] + libpng_jll v1.6.38+0
#   [f27f6e37] + libvorbis_jll v1.3.7+0
#   [1270edf5] + x264_jll v2021.5.5+0
#   [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v0.9.1+5
#   [0dad84c5] + ArgTools
#   [56f22d72] + Artifacts
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [f43a241f] + Downloads
#   [b77e0a4c] + InteractiveUtils
#   [4af54fe1] + LazyArtifacts
#   [b27032c2] + LibCURL
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [ca575930] + NetworkOptions
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [9abbd945] + Profile
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [1a1011a3] + SharedArrays
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [fa267f1f] + TOML
#   [a4e569a6] + Tar
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   [e66e0078] + CompilerSupportLibraries_jll
#   [deac9b47] + LibCURL_jll
#   [29816b5a] + LibSSH2_jll
#   [c8ffd9c3] + MbedTLS_jll
#   [14a3606d] + MozillaCACerts_jll
#   [05823500] + OpenLibm_jll
#   [83775a58] + Zlib_jll
#   [8e850ede] + nghttp2_jll
#   [3f19e933] + p7zip_jll
#       From worker 2:	Your GR installation is incomplete. Rerunning build step for GR package.
#       From worker 2:	ERROR: LoadError: LoadError: InitError: Evaluation into the closed module `GR` breaks incremental compilation because the side effects will not be permanent. This is likely due to some other module mutating `GR` with `eval` during precompilation - don't do this.
#       From worker 2:	Stacktrace:
#       From worker 2:	  [1] eval
#       From worker 2:	    @ .\boot.jl:360 [inlined]
#       From worker 2:	  [2] __init__()
#       From worker 2:	    @ GR C:\Users\james\.julia\packages\GR\Pwj8N\src\GR.jl:355
#       From worker 2:	  [3] _include_from_serialized(path::String, depmods::Vector{Any})
#       From worker 2:	    @ Base .\loading.jl:696
#       From worker 2:	  [4] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String)
#       From worker 2:	    @ Base .\loading.jl:782
#       From worker 2:	  [5] _require(pkg::Base.PkgId)
#       From worker 2:	    @ Base .\loading.jl:1020
#       From worker 2:	  [6] require(uuidkey::Base.PkgId)
#       From worker 2:	    @ Base .\loading.jl:936
#       From worker 2:	  [7] require(into::Module, mod::Symbol)
#       From worker 2:	    @ Base .\loading.jl:923
#       From worker 2:	  [8] include(mod::Module, _path::String)
#       From worker 2:	    @ Base .\Base.jl:386
#       From worker 2:	  [9] include(x::String)
#       From worker 2:	    @ Plots C:\Users\james\.julia\packages\Plots\LSKOd\src\Plots.jl:1
#       From worker 2:	 [10] top-level scope
#       From worker 2:	    @ C:\Users\james\.julia\packages\Plots\LSKOd\src\Plots.jl:231
#       From worker 2:	 [11] include
#       From worker 2:	    @ .\Base.jl:386 [inlined]
#       From worker 2:	 [12] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt64}}, source::Nothing)
#       From worker 2:	    @ Base .\loading.jl:1235
#       From worker 2:	 [13] top-level scope
#       From worker 2:	    @ none:1
#       From worker 2:	 [14] eval
#       From worker 2:	    @ .\boot.jl:360 [inlined]
#       From worker 2:	 [15] eval(x::Expr)
#       From worker 2:	    @ Base.MainInclude .\client.jl:446
#       From worker 2:	 [16] top-level scope
#       From worker 2:	    @ none:1
#       From worker 2:	during initialization of module GR
#       From worker 2:	in expression starting at C:\Users\james\.julia\packages\Plots\LSKOd\src\backends\gr.jl:6
#       From worker 2:	in expression starting at C:\Users\james\.julia\packages\Plots\LSKOd\src\Plots.jl:1

# %% [markdown]
# ## 绘制二维曲面

# %%
f(x, y) = x * exp(-x^2-y^2)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# ## Julia里的广播
# 广播不会让Julia变得更快，它只是把for循环藏起来了。

# %%
g(x, y) = x + y
# Out:
# g (generic function with 1 method)

# %%
g.([1,2], [3,4])
# Out:
# 2-element Vector{Int64}:
#  4
#  6

# %%
g.([1,2],3)
# Out:
# 2-element Vector{Int64}:
#  4
#  5

# %%
X1 = reshape([1,2,3,4,3,4,5,6], (4, 2))
Y1 = [2,3,5,7]
g.(X1,Y1)
# Out:
# 4×2 Matrix{Int64}:
#   3   5
#   5   7
#   8  10
#  11  13

# %% [markdown]
# 在内存中的不同排列方式会影响代码的写法，进而影响计算效率。

# %%
x6 = reshape(1:12,2,3,2)
# Out:
# 2×3×2 reshape(::UnitRange{Int64}, 2, 3, 2) with eltype Int64:
# [:, :, 1] =
#  1  3  5
#  2  4  6
#
# [:, :, 2] =
#  7   9  11
#  8  10  12

# %%
y6 = permutedims(x6, (3,1,2))
# Out:
# 2×2×3 Array{Int64, 3}:
# [:, :, 1] =
#  1  2
#  7  8
#
# [:, :, 2] =
#  3   4
#  9  10
#
# [:, :, 3] =
#   5   6
#  11  12

# %% [markdown]
# ## 向量化

# %% [markdown]
# - f(x::Real, y::Real) = x * y
# - f(X::AbstractArray, y::AbstractArray) = X .* Y

# %% [markdown]
# Julia不推荐向量化编程，这是因为：~~~

# %%
muladd
# Out:
# muladd (generic function with 21 methods)

# %%
muladd.([1,2,3],[2,3,4],[1,2,3])
# Out:
# 3-element Vector{Int64}:
#   3
#   8
#  15

# %%
muladd_vec(A::AbstractArray, B, C) = A .* B + C
muladd_temp(a::Number, b, c) = a * b + c
muladd_broadcast(A::AbstractArray, B, C) = muladd_temp.(A, B, C)
# Out:
# muladd_broadcast (generic function with 1 method)

# %%
A = rand(4,2)
B = rand(4,2)
C = rand(4,2)

@btime muladd.($A,$B,$C)
@btime muladd_vec($A,$B,$C)
@btime muladd_broadcast($A,$B,$C)
# Out:
#   61.633 ns (1 allocation: 144 bytes)
#   122.591 ns (2 allocations: 288 bytes)
#   66.904 ns (1 allocation: 144 bytes)
# 4×2 Matrix{Float64}:
#  0.246729  0.847313
#  0.261622  1.03784
#  1.25908   0.225348
#  0.373756  0.692663

# %% [markdown]
# 上面的例子表明向量化不仅占用了更多内存，而且还慢了很多。

# %% [markdown]
# ## View 和 Copy

# %%
X = [1,2,3,4]
Y = X[1:4]
Y[1] = 0
@show X,Y;
# Out:
# (X, Y) = ([1, 2, 3, 4], [0, 2, 3, 4])

# %%
X = [1,2,3,4]
Y = @view X[1:4]
Y[1] = 0
@show X,Y;
# Out:
# (X, Y) = ([0, 2, 3, 4], [0, 2, 3, 4])

# %% [markdown]
# ## Ex. MNIST数据集

# %% [markdown]
# ## 向量化对并行计算是很有用的

# %%
function g_kernel(x)
    sleep(0.01)
    return x
end
# Out:
# g_kernel (generic function with 1 method)

# %%
function g_seq(X)
    out = similar(X)
    for i in eachindex(X)
        out[i] = g_kernel(X[i])
    end
    return out
end
# Out:
# g_seq (generic function with 1 method)

# %%
function g_threads(X)
    out = similar(X)
    Threads.@threads for i in eachindex(X)
        out[i] = g_kernel(X[i])
    end
    return out
end
# Out:
# g_threads (generic function with 1 method)

# %%
X = rand(4,4)
@btime g_seq($X)
@btime g_threads($X)
# Out:
#   243.121 ms (85 allocations: 2.52 KiB)
#   241.295 ms (91 allocations: 3.11 KiB)
# 4×4 Matrix{Float64}:
#  0.406844  0.184595  0.448362   0.101233
#  0.411754  0.895952  0.93337    0.0554428
#  0.864226  0.717108  0.0495627  0.98938
#  0.240794  0.482872  0.504993   0.908991
